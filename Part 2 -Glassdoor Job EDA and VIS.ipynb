# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv('salary_data_cleaned.csv')

# %%
data.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
data.age.hist()
# Out:
# <AxesSubplot:>

# %%
data.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
data.desc_len.hist()
# Out:
# <AxesSubplot:>

# %%
data.job_state.value_counts()[:15].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data.python_yn)
# Out:
# C:\Users\mohamed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='python_yn', ylabel='count'>

# %%
sns.countplot(data.aws)
# Out:
# C:\Users\mohamed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='aws', ylabel='count'>

# %%
sns.countplot(data.excel)
# Out:
# C:\Users\mohamed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='excel', ylabel='count'>

# %%
sns.countplot(data.R_yn)
# Out:
# C:\Users\mohamed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='R_yn', ylabel='count'>

# %%
sns.countplot(data.spark)
# Out:
# C:\Users\mohamed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='spark', ylabel='count'>

# %%
data.job_state.value_counts()[:11].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
data.corr()
# Out:
#               Rating   Founded  min_salary  max_salary  avg_salary  \
# Rating      1.000000  0.332927   -0.007825    0.027668    0.013492
# Founded     0.332927  1.000000   -0.038513    0.001069   -0.015149
# min_salary -0.007825 -0.038513    1.000000    0.944186    0.980031
# max_salary  0.027668  0.001069    0.944186    1.000000    0.990833
# avg_salary  0.013492 -0.015149    0.980031    0.990833    1.000000
# same_state  0.085033  0.171512   -0.045114   -0.026738   -0.034641
# age         0.024665  0.143634    0.001352    0.031373    0.019492
# python_yn   0.144665  0.103183    0.339425    0.312443    0.327796
# R_yn       -0.004472  0.016045   -0.040105   -0.039019   -0.040000
# spark       0.156982  0.066978    0.171094    0.176259    0.176559
# aws         0.117049 -0.011123    0.168418    0.169494    0.171379
# excel      -0.036466 -0.035567   -0.062074   -0.052674   -0.057252
# desc_len   -0.012281  0.083119    0.069666    0.083228    0.078808
#
# ...

# %%
plt.figure(figsize=(16,8))
sns.heatmap(data = round(data.corr() ,1) , annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,6))
data['Type of ownership'].value_counts()[:5].plot(kind = 'pie' , autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Type of ownership'>

# %%
plt.figure(figsize=(12,6))
sns.countplot(data = data , x = 'Size')
# plt.xticks(routation = 90)
plt.xticks(rotation = 90)
plt.show()

# %%
data.sample()
# Out:
#           Job Title              Salary Estimate  \
# 428  Data Scientist  $94K-$139K (Glassdoor est.)
#
#                                        Job Description  Rating Company Name  \
# 428  About Citi\n\nCiti, the leading global bank, h...     3.6    Citi\n3.6
#
#             Location  Headquarters              Size  Founded  \
# 428  Jersey City, NJ  New York, NY  10000+ employees     1812
#
#     Type of ownership  ... company_txt job_state same_state  age  python_yn  \
# 428  Company - Public  ...        Citi        NJ          0  210          0
#
#      R_yn  spark aws excel  desc_len
# 428     0      0   0     1      3948
#
# [1 rows x 27 columns]

# %%
data.same_state.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
data.company_txt.value_counts()[:15].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
data.same_state.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df_cat = data[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt', 'job_state','same_state', 'python_yn', 'R_yn',
       'spark', 'aws', 'excel']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    chart = sns.barplot(x=cat_num[cat_num.index[:10]], y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()

# %%
data.sample()
# Out:
#                             Job Title               Salary Estimate  \
# 86  Staff Data Scientist - Technology  $106K-$172K (Glassdoor est.)
#
#                                       Job Description  Rating  Company Name  \
# 86  Position Summary...\nDrives the execution of m...     3.2  Walmart\n3.2
#
#      Location     Headquarters              Size  Founded Type of ownership  \
# 86  Plano, TX  Bentonville, AR  10000+ employees     1962  Company - Public
#
#     ... company_txt job_state same_state age  python_yn  R_yn  spark aws  \
# 86  ...     Walmart        TX          0  60          0     0      0   0
#
#    excel  desc_len
# 86     0      3934
#
# [1 rows x 27 columns]

# %%
sns.regplot(data = data , y = 'Rating' , x = data.min_salary)
# Out:
# <AxesSubplot:xlabel='min_salary', ylabel='Rating'>

# %%
sns.regplot(data = data , y = 'Rating' , x = data.max_salary)
# Out:
# <AxesSubplot:xlabel='max_salary', ylabel='Rating'>

# %%
sns.regplot(data = data , y = 'Rating' , x = data.avg_salary)
# Out:
# <AxesSubplot:xlabel='avg_salary', ylabel='Rating'>
